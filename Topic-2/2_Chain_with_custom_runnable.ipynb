# %% [markdown]
# #### CHAIN WITH CUSTOM RUNNABLE

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_community.chat_models import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import warnings
warnings.filterwarnings("ignore")

# %%
# TASK -1 [Prompt]

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant"),
    ("human", "{input}")
])

# %%
# TASK - 2 [LLM]

llm = ChatOllama(
    model="mistral:latest",
    temperature=0.7
)

# %%
# TASK - 3 [Str Parser]

str_parser = StrOutputParser()

# %%
# TASK - 4 [Custom Runnable]
from langchain_core.runnables import RunnableLambda

def dictionary_maker(text:str)-> dict:

    return {"text" : text}

dictionary_maker_runnable = RunnableLambda(dictionary_maker)

# %%
# TASK - 5 [Template For Post]

prompt_post = ChatPromptTemplate.from_messages(
    messages=[
        ("system", "You're a social media post generator. "),
        ("human", "Create a post for the following text for LinkedIn: {text}"),
    ]
)

# %%
# TASK - 6 [Generate the Post]

llm = ChatOllama(
    model="mistral:latest",
    temperature=0.7
)

# %%
# TASK - 7 [Str Parser]

str_parser = StrOutputParser()

# %%
# CHAIN

chain = prompt_template | llm | str_parser | dictionary_maker_runnable | prompt_post | llm | str_parser

chain.invoke("What is the capital of France?")
# Out:
# " Post title: Fun Fact Friday 🌉\n\nDid you know? The vibrant and enchanting city that never sleeps, Paris, is not just a global fashion hub or romantic getaway, but it's also the capital city of France! 🇫🇷 Imagine sipping café au lait while discussing business strategies in one of the many historic cafes that have inspired great minds throughout history. Here's to a week full of success and Parisian charm! #Paris #CapitalCity #France #FridayMotivation"
