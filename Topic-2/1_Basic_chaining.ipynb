# %% [markdown]
# ### CHAINS In Langchain

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_community.chat_models import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ##### <h>*</h> Multiple Tasks

# %%
# TASK -1 [Prompt]

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant"),
    ("human", "{input}")
])

# %%
# TASK - 2 [LLM]

llm = ChatOllama(
    model="mistral:latest",
    temperature=0.7
)

# %%
# TASK - 3 [Str Parser]

str_parser = StrOutputParser()

# %% [markdown]
# ##### 1. Mannualy invoking all task

# %%
template=prompt_template.invoke({"input":"What is capital of France?"})
res=llm.invoke(template)
str_parser=res.content
str_parser
# Out:
# " The capital of France is Paris. Paris is a city rich in culture, art, and history, and it's one of the most visited cities in the world. It's known for landmarks like the Eiffel Tower, Louvre Museum, and Notre-Dame Cathedral."
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ##### 2. Chaining invoke all task

# %%
chain_task=prompt_template | llm | str_parser
chain_task.invoke({"input":"What is capital of France?"})
# Out:
# ' The capital of France is Paris.'

# %% [markdown]
# #### 2.1 Another way of chaining task to run

# %%
from langchain_core.runnables import RunnableSequence

chain_1 = RunnableSequence(prompt_template, llm, str_parser)

chain_1.invoke("What is the capital of France?")
# Out:
# ' The capital of France is Paris.'
